# %% [markdown]
# <a href="https://colab.research.google.com/github/MelquisedecIquin/CPE-031-Visualization-and-Data-Analysis/blob/main/Hands_On_Activity_12___Data_Dashboard_Taxonomies_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 12 | Data Dashboard Taxonomies**
#
#
#
#
#
# ---

# %% [markdown]
# Name(s): <br>
# Iquin, Melquisedec D.<br>
# Javillonar, Madhel Kathlyn
# Course Code and Title : CPE031/Visualization and Data Analysis<br>
# Date Submitted : 11/06/2025 <br>
# Instructor : Engr. Ma. Rizette Sayo
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to demonstrate students’ ability to design, interpret, and evaluate data dashboards. Students will apply principles of effective data dashboards, understand data update mechanisms, explore user interaction features, and relate dashboards to their organizational functions.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Identify the key principles that make data dashboards effective communication tools.
#
# 2. Explain how data updates, user interaction, and organizational function shape dashboard design.
#
# 3. Build an interactive data dashboard in Python using sample data to visualize multiple business metrics.

# %% [markdown]
# **3. Discussions:**
#
# A data dashboard is a visual interface that displays key information and performance indicators in a concise and interactive manner. Dashboards consolidate multiple data sources to provide users with insights for decision-making and performance tracking.
#
# Principles of Effective Dashboards:
#
# Clarity and Simplicity: Visuals should be easy to read and interpret.
#
# Real-Time or Dynamic Data: Dashboards often pull updated data automatically.
#
# Interactivity: Users should be able to filter, sort, or drill down into specific metrics.
#
# Action-Oriented Insights: The dashboard should guide users toward decisions or next steps.
#
# Taxonomies of Data Dashboards:
#
# Data Updates – Dashboards can show static (snapshot) or dynamic (real-time) data.
#
# User Interaction – Some dashboards allow filtering, searching, and selecting parameters.
#
# Organizational Function – Dashboards can serve strategic, analytical, or operational functions.
#
# For example:
#
# Strategic dashboards help top management monitor KPIs.
#
# Analytical dashboards help analysts explore data trends.
#
# Operational dashboards support real-time monitoring of systems and workflows.

# %% [markdown]
# **4. Procedures:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install plotly pandas
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
# Simulated company performance data
np.random.seed(42)
months = pd.date_range("2024-01-01", periods=12, freq="M")
regions = ["North", "South", "East", "West"]
products = ["Laptop", "Tablet", "Phone"]

data = {
    "Month": np.random.choice(months, 200),
    "Region": np.random.choice(regions, 200),
    "Product": np.random.choice(products, 200),
    "Sales": np.random.randint(5000, 20000, 200),
    "Profit": np.random.randint(500, 5000, 200)
}

df = pd.DataFrame(data)
df.head()
# Out:
# /tmp/ipython-input-3445195635.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   months = pd.date_range("2024-01-01", periods=12, freq="M")
#        Month Region Product  Sales  Profit
# 0 2024-07-31   West  Laptop  15738    4012
# 1 2024-04-30   West  Laptop  13945    1756
# 2 2024-11-30   East  Laptop   7082    3876
# 3 2024-08-31   East   Phone  15966    3986
# 4 2024-05-31  South   Phone  16088    4084

# %%
# Aggregated views
sales_by_region = df.groupby("Region", as_index=False)["Sales"].sum()
sales_by_product = df.groupby("Product", as_index=False)["Sales"].sum()
sales_trend = df.groupby("Month", as_index=False)["Sales"].sum().sort_values("Month")

# Create dashboard layout
fig = make_subplots(rows=2, cols=2,
                    subplot_titles=("Sales by Region", "Sales by Product", "Monthly Sales Trend", "Profit vs Sales"),
                    specs=[[{"type": "bar"}, {"type": "pie"}],
                           [{"colspan": 2}, None]])

# Add charts
fig.add_trace(go.Bar(x=sales_by_region["Region"], y=sales_by_region["Sales"], name="Region Sales"), row=1, col=1)
fig.add_trace(go.Pie(labels=sales_by_product["Product"], values=sales_by_product["Sales"], name="Product Sales"), row=1, col=2)
fig.add_trace(go.Scatter(x=sales_trend["Month"], y=sales_trend["Sales"], mode="lines+markers", name="Monthly Trend"), row=2, col=1)

fig.update_layout(height=700, width=950, title_text="📊 Interactive Data Dashboard Example")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b3f38d2c-37ee-48f3-83d8-a43a920dcaa7" class="plotly-graph-div" style="height:700px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3f38d2c-37ee-48f3-83d8-a43a920dcaa7")) {                    Plotly.newPlot(                        "b3f38d2c-37ee-48f3-83d8-a43a920dcaa7",                        [{"name":"Region Sales","x":["East","North","South","West"],"y":[532002,536654,541249,825364],"type":"bar","xaxis":"x","yaxis":"y"},{"labels":["Laptop","Phone","Tablet"],"name":"Product Sales","values":[884318,668481,882470],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.625,1.0]}},{"mode":"lines+markers","name":"Monthly Trend","x":["2024-01-31T00:00:00","2024-02-29T00:00:00","2024-03-31T00:00:00","2024-04-30T00:00:00","2024-05-31T00:00:00","2024-06-30T00:00:00","2024-07-31T00:00:00","2024-08-31T00:00:00","2024-09-30T00:00:00","2024-10-31T00:00:00","2024-11-30T00:00:00","2024-12-31T00:00:00"],"y":[184076,144338,227239,164009,179320,106348,279015,200151,225316,234621,152441,338395],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpola ...

# %%
# Interactive dashboard: filterable by product
fig = px.bar(df, x="Region", y="Sales", color="Product", barmode="group",
             title="Interactive Dashboard: Sales by Region and Product",
             hover_data=["Profit"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="077f0062-1922-478f-a2fe-0286dd882796" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("077f0062-1922-478f-a2fe-0286dd882796")) {                    Plotly.newPlot(                        "077f0062-1922-478f-a2fe-0286dd882796",                        [{"alignmentgroup":"True","customdata":[[4012],[1756],[3876],[1896],[4137],[3203],[1853],[857],[3519],[1167],[4968],[4685],[1039],[4636],[4275],[3279],[2081],[4500],[2133],[2652],[2500],[4678],[2548],[2323],[2581],[3919],[3537],[3778],[1829],[4761],[1858],[3677],[2628],[3972],[3093],[4542],[3447],[780],[1166],[4688],[1171],[3622],[3093],[2468],[2253],[2796],[2761],[3378],[4144],[802],[555],[1025],[2625],[864],[2031],[3586],[1213],[1796],[566],[4507],[2972],[3160],[4014],[4312],[3948],[1812],[2824],[2105],[3063],[2897],[4235],[3090]],"hovertemplate":"Product=Laptop\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Laptop","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Laptop","offsetgroup":"Laptop","orientation":"v","showlegend":true,"textposition":"auto","x":["West","West","East","West","West","North","North","South","West","West","South","South","North","West","North","North","West","West","East","East","East","South","South","West","West","North","East","East","North","West","North","East","West","South","East","West","North","South","West","East","East","East","West","West","South","West","North","East","West","South","West","South","East","North","South","East","North","North","West","North","West","North","East","South","South","South","North","South","West","South","North","East"],"xaxis":"x","y":[15738,13945,7082,17377,13967,14817,5417,8974,8267,5825,12668,14708,12543,5728,16540,16000,10988,8766,10644,15518,10917,5728,6365,12186,19512,18923,16769,16332,10588,6062,7156,12860,10161,11541,10334,9846,16516,6542,11313,18704,16185,14409,15578,16911,18807,14580,15048,14872,12494,8141,8486,6810,7923,15406,16794,9268,9849,14273,14086,17477,5504,6214,12576,18428,5133,7105,11316,9910,18460,16476,17490,14442],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3986],[4084],[3331],[4219],[3245],[3279],[3008],[1424],[4985],[2444],[1297],[2324],[3636],[2693],[1010],[904],[2168],[4136],[1216],[1173],[2665],[1270],[2484],[1577],[888],[3314],[2517],[4844],[2680],[4079],[3531],[4664],[4323],[2406],[1260],[1399],[2387],[3766],[4400],[2786],[4702],[4932],[2555],[3266],[3787],[2575],[625],[2656],[4706],[3239],[2475],[1376],[1960],[3209],[2233],[4017],[3370]],"hovertemplate":"Product=Phone\u003cbr\u003eRegion=%{x}\u003cbr\u003eSales=%{y}\u003cbr\u003eProfit=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Phone","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Phone","offsetgroup":"Phone","orientation":"v","showlegend":true,"textposition":"auto","x":["East","South","North","East","North","North","East","South","East","North","South","North","South","West","West","North","West","West","East","East","South","West","West","West","West","East","West","South","North","East","South","South","South","North","West","North","North","North","East","West","West","West","South","West","North","West","West","West","East","West","East","East","South","South","East","East","South"],"xaxis":"x","y":[15966,16088,13808,16338,5412,12587,12164,13867,7967,6122,10073,7143,11806,12357,19552,9968,17144,13787,5698,12400,13082,9171,15011,5717,9946,13335,16414,15808,10305,9729,14348,12330,11801,11731,12241,7539,18964,6191,6540,6365,13691,9312,6324,15019,10301,9748,18971,15150,15188,6531,5823,10029,8627,17972,6852,16125,16003],"yaxis":"y","type":"bar"},{"alignmentgro ...

# %% [markdown]
# **Task 1:** Principles of Effective Data Dashboards
#
# Create your own version of the dashboard above using a different dataset (e.g., student performance, store sales, or IoT sensor readings).
# Ensure that your dashboard demonstrates:
#
# Clarity and simplicity in layout
#
# Appropriate chart types for your data
#
# Use of color and labels to improve readability

# %%
#Code Here
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

data = pd.DataFrame({
    "Student": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Hannah"],
    "Math": [85, 78, 92, 88, 70, 95, 80, 77],
    "Science": [90, 82, 88, 85, 75, 92, 84, 80],
    "English": [78, 85, 80, 90, 88, 82, 76, 89]
})

avg_scores = data[["Math", "Science", "English"]].mean().reset_index()
avg_scores.columns = ["Subject", "Average_Score"]

fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=("Average Score per Subject", "Distribution of Student Scores")
)

bar = go.Bar(
    x=avg_scores["Subject"],
    y=avg_scores["Average_Score"],
    marker_color=["skyblue", "orange", "green"],
    text=avg_scores["Average_Score"],
    textposition="auto"
)
fig.add_trace(bar, row=1, col=1)

for subject in ["Math", "Science", "English"]:
    fig.add_trace(
        go.Box(
            y=data[subject],
            name=subject,
            marker_color="lightcoral"
        ),
        row=1, col=2
    )

fig.update_layout(
    title_text="Student Performance Dashboard",
    showlegend=False,
    height=500,
    width=900
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2d332e6c-b3f5-4dcc-838d-5eee3a36cf1c" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d332e6c-b3f5-4dcc-838d-5eee3a36cf1c")) {                    Plotly.newPlot(                        "2d332e6c-b3f5-4dcc-838d-5eee3a36cf1c",                        [{"marker":{"color":["skyblue","orange","green"]},"text":[83.125,84.5,83.5],"textposition":"auto","x":["Math","Science","English"],"y":[83.125,84.5,83.5],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"lightcoral"},"name":"Math","y":[85,78,92,88,70,95,80,77],"type":"box","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"lightcoral"},"name":"Science","y":[90,82,88,85,75,92,84,80],"type":"box","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"lightcoral"},"name":"English","y":[78,85,80,90,88,82,76,89],"type":"box","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5 ...

# %% [markdown]
# **Task 2:** Data Dashboard Taxonomies
#
# Add interactivity features such as:
#
# A dropdown menu to select regions or products
#
# A dynamic update (simulating real-time data) using Python’s update functions
#
# Explain how your dashboard fits into:
#
# Data Update Type (Static, Scheduled, or Real-Time)
#
# User Interaction (Filter, Drilldown, etc.)
#
# Organizational Function (Strategic, Analytical, Operational)

# %%
#Code Here
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

data = pd.DataFrame({
    "Region": ["North", "South", "East", "West"] * 5,
    "Product": ["A", "B", "C", "D", "E"] * 4,
    "Sales": np.random.randint(50, 200, 20)
})

fig = px.bar(
    data_frame=data,
    x="Product",
    y="Sales",
    color="Region",
    barmode="group",
    title="Sales Dashboard"
)

fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(label="All Regions",
                     method="update",
                     args=[{"visible": [True]*20},
                           {"title": "Sales Dashboard - All Regions"}]),
                dict(label="North",
                     method="update",
                     args=[{"visible": [r=="North" for r in data["Region"]]},
                           {"title": "Sales Dashboard - North Region"}]),
                dict(label="South",
                     method="update",
                     args=[{"visible": [r=="South" for r in data["Region"]]},
                           {"title": "Sales Dashboard - South Region"}])
            ]),
            direction="down",
            showactive=True,
            x=0.1,
            xanchor="left",
            y=1.15,
            yanchor="top"
        )
    ]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0967ba9c-c272-4ecc-a26a-b867c71385c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0967ba9c-c272-4ecc-a26a-b867c71385c6")) {                    Plotly.newPlot(                        "0967ba9c-c272-4ecc-a26a-b867c71385c6",                        [{"alignmentgroup":"True","hovertemplate":"Region=North\u003cbr\u003eProduct=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"North","offsetgroup":"North","orientation":"v","showlegend":true,"textposition":"auto","x":["A","E","D","C","B"],"xaxis":"x","y":[89,124,167,128,182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=South\u003cbr\u003eProduct=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"South","offsetgroup":"South","orientation":"v","showlegend":true,"textposition":"auto","x":["B","A","E","D","C"],"xaxis":"x","y":[85,53,162,185,119],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=East\u003cbr\u003eProduct=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"East","offsetgroup":"East","orientation":"v","showlegend":true,"textposition":"auto","x":["C","B","A","E","D"],"xaxis":"x","y":[55,128,143,75,167],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=West\u003cbr\u003eProduct=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"West","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"West","offsetgroup":"West","orientation":"v","showlegend":true,"textposition":"auto","x":["D","C","B","A","E"],"xaxis":"x","y":[115,183,111,93,117],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111, ...

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# Create a mini dashboard project that tracks student grades or attendance:
#
# 1. Include 3 visualizations (e.g., average grades by subject, attendance by week, and performance trend).
#
# 2. Add at least one interactive feature (dropdown or slider).
#
# 3. Explain how your dashboard helps an instructor or department make data-driven decisions.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

data = pd.DataFrame({
    "Student": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Hannah"],
    "Subject": ["Math", "Science", "English", "Math", "Science", "English", "Math", "Science"],
    "Week1": [85, 90, 78, 88, 75, 82, 80, 85],
    "Week2": [88, 92, 80, 90, 78, 84, 82, 87],
    "Week3": [90, 95, 85, 92, 80, 86, 85, 88],
    "Attendance": [1, 0.9, 1, 0.95, 0.8, 0.85, 0.9, 1]
})

avg_grades = data[["Week1","Week2","Week3"]].mean().reset_index()
avg_grades.columns = ["Week", "Average_Grade"]

fig = make_subplots(
    rows=1, cols=3,
    subplot_titles=("Average Grades by Week", "Attendance by Student", "Performance Trend")
)

line = go.Scatter(
    x=avg_grades["Week"],
    y=avg_grades["Average_Grade"],
    mode="lines+markers",
    line=dict(color="blue"),
    name="Average Grade"
)
fig.add_trace(line, row=1, col=1)

bar = go.Bar(
    x=data["Student"],
    y=data["Attendance"],
    marker_color="orange",
    name="Attendance"
)
fig.add_trace(bar, row=1, col=2)

for student in data["Student"]:
    fig.add_trace(
        go.Scatter(
            x=["Week1","Week2","Week3"],
            y=data.loc[data["Student"]==student, ["Week1","Week2","Week3"]].values.flatten(),
            mode="lines+markers",
            name=student,
            visible=True
        ),
        row=1, col=3
    )

buttons = [dict(label=student,
                method="update",
                args=[{"visible":[True if t==student else False for t in data["Student"]]},
                      {"title":f"Performance Trend - {student}"}]) for student in data["Student"]]
fig.update_layout(updatemenus=[dict(buttons=buttons, direction="down", x=0.5, y=1.2, showactive=True)])

fig.update_layout(height=500, width=1200, title_text="Student Grades and Attendance Dashboard")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0bfcd363-7680-4885-80da-baab6b37474a" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bfcd363-7680-4885-80da-baab6b37474a")) {                    Plotly.newPlot(                        "0bfcd363-7680-4885-80da-baab6b37474a",                        [{"line":{"color":"blue"},"mode":"lines+markers","name":"Average Grade","x":["Week1","Week2","Week3"],"y":[82.875,85.125,87.625],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"orange"},"name":"Attendance","x":["Alice","Bob","Charlie","David","Eva","Frank","Grace","Hannah"],"y":[1.0,0.9,1.0,0.95,0.8,0.85,0.9,1.0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"mode":"lines+markers","name":"Alice","visible":true,"x":["Week1","Week2","Week3"],"y":[85,88,90],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"Bob","visible":true,"x":["Week1","Week2","Week3"],"y":[90,92,95],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"Charlie","visible":true,"x":["Week1","Week2","Week3"],"y":[78,80,85],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"David","visible":true,"x":["Week1","Week2","Week3"],"y":[88,90,92],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"Eva","visible":true,"x":["Week1","Week2","Week3"],"y":[75,78,80],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"Frank","visible":true,"x":["Week1","Week2","Week3"],"y":[82,84,86],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"Grace","visible":true,"x":["Week1","Week2","Week3"],"y":[80,82,85],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines+markers","name":"Hannah","visible":true,"x":["Week1","Week2","Week3"],"y":[85,87,88],"type":"scatter","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444, ...

# %% [markdown]
# **Explination** <br>
# -
#
# - This dashboard helps instructors or departments by showing average grades per week, student attendance, and individual performance trends. The dropdown allows focusing on a single student’s progress. This supports data-driven decisions like identifying students who may need extra help or adjusting teaching strategies.

# %% [markdown]
# **6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# -> I can see that tracking student grades and attendance helps me understand overall class performance. The dashboard shows me which students are keeping up and which may need extra support. By looking at trends over weeks, I can identify patterns in learning and attendance. This allows me to make better decisions to improve student outcomes and provide targeted guidance.
